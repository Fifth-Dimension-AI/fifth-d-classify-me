# %%
import sys
sys.path.append('..')
from app import evaluate_v2
import json
import os
from importlib import reload

# %%
def load_json_file(path:str)-> list|dict :

    with open(path,"r") as file:
        data = json.load(file)

    classes = data['classes']
    options = data['options']
    queries = [a['query'] for a in data['queries']]
    
    return data, classes, options, queries

data, classes, options, queries = load_json_file('../data/case_test.json')

# %%
options
# Out:
# {'multilabel': False, 'reasoning': True}

# %%
evaluate_original.form_request(queries[0], classes, options)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 evaluate_original.form_request(queries[0], classes, options)
#
# File c:\Users\EliasMelas\Documents\property\fifth_dimension_AI\fifth-d-classify-me\notebooks\..\app\evaluate_original.py:39, in form_request(query, classes, options)
#      36 def form_request(query: str, classes: List[Class], options: Options) -> dict:
#      37     return {
#      38         "query": query,
# ---> 39         "classes": [x.model_dump() for x in classes],
#      40         "options": options.model_dump(),
#      41     }
#
# AttributeError: 'dict' object has no attribute 'model_dump'

# %%
reload(evaluate_original)

data_dir = "../data"
test_cases = [
    "case_1.json",
    "case_2.json",
    "case_3.json",
]
test_cases = [os.path.join(data_dir, test_case) for test_case in test_cases]
print(test_cases)
evaluate_original.iterate_test_cases(test_cases)
# Out:
# ['../data\\case_1.json', '../data\\case_2.json', '../data\\case_3.json']
# ...
